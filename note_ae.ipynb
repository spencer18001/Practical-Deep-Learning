# %% [markdown]
# <a href="https://colab.research.google.com/github/spencer18001/Practical-Deep-Learning/blob/main/note_ae.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## AutoEncoder (AE)

# %% [markdown]
# 參考:
# - [Autoencoders and the Denoising Feature: From Theory to Practice…](https://towardsdatascience.com/autoencoders-and-the-denoising-feature-from-theory-to-practice-db7f7ad8fc78/)

# %% [markdown]
# #### generalities about autoencoders

# %% [markdown]
# - learn latent representation or codings

# %% [markdown]
# <img src='https://towardsdatascience.com/wp-content/uploads/2020/11/0q3rUaf3JGbLlOopP.png' width='700px'>

# %% [markdown]
# - undercomplete autoencoder $k \ll p$
#     - application: dimensionality reduction
# - overcomplete autoencoder $k \gg p$

# %% [markdown]
# #### sparse autoencoders

# %% [markdown]
# - trained with a sparsity penalty added to his original loss function
#   - $\mathcal{L}(x,D(E(x)))+\Omega(E(x))$

# %% [markdown]
# #### denoising autoencoders

# %% [markdown]
# - add noise to the inputs forces our model to learn important features from our data

# %% [markdown]
# <img src='https://towardsdatascience.com/wp-content/uploads/2020/11/0ECdHu2yeal38Jl3P-768x371.png'>
